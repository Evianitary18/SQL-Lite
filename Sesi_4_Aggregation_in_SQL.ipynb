# %% [markdown]
# <a href="https://colab.research.google.com/github/Evianitary18/SQL-Lite/blob/main/Sesi_4_Aggregation_in_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import sqlite3 as sql

# %%
db = sql.connect('northwind.db')

# %%
# query di bawah akan menampilkan tabel - tabel yang ada di database kita
query = """
SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';
"""

# %%
# buat variabel cursor dari koneksi ke database kita
cursor = db.cursor()

# %%
# menjalankan query dan menampilkan hasil
cursor.execute(query)
print(cursor.fetchall())
# Out:
# [('Suppliers',), ('Shippers',), ('Employees',), ('Customers',), ('Orders',), ('Categories',), ('Products',), ('OrderDetails',)]

# %% [markdown]
# ### Functions & Aggregation
#
# SQL has built-in functions, which vary from one DBMS to another. The SQL cheatsheet lists most of the functions supported by SQLite.
#
# Most SQL functions aggregate data in a column, summarizing that column somehow.

# %%
pd.read_sql("SELECT * FROM orders LIMIT 3;", db)
# Out:
#    OrderID CustomerID  EmployeeID                OrderDate  \
# 0    10248      VINET           5  2014-07-04 08:00:00.000
# 1    10249      TOMSP           6  2014-07-05 04:00:00.000
# 2    10250      HANAR           4  2014-07-08 15:00:00.000
#
#               RequiredDate              ShippedDate  ShipVia  Freight  \
# 0  2014-08-01 00:00:00.000  2014-07-16 00:00:00.000        3    32.38
# 1  2014-08-16 00:00:00.000  2014-07-10 00:00:00.000        1    11.61
# 2  2014-08-05 00:00:00.000  2014-07-12 00:00:00.000        2    65.83
#
#                     ShipName         ShipAddress        ShipCity ShipRegion  \
# 0  Vins et alcools Chevalier  59 rue de l'Abbaye           Reims       None
# 1         Toms Spezialitäten       Luisenstr. 48         Münster       None
# 2              Hanari Carnes     Rua do Paço, 67  Rio de Janeiro         RJ
#
#   ShipPostalCode ShipCountry
# 0          51100      France
# 1          44087     Germany
# 2      05454-876      Brazil

# %%
pd.read_sql("SELECT COUNT(*) FROM suppliers;", db)
# Out:
#    COUNT(*)
# 0        29

# %%
pd.read_sql("SELECT UPPER(City), * FROM Suppliers LIMIT 3;", db)
# Out:
#    UPPER(City)  SupplierID                 CompanyName       ContactName  \
# 0       LONDON           1              Exotic Liquids  Charlotte Cooper
# 1  NEW ORLEANS           2  New Orleans Cajun Delights     Shelley Burke
# 2    ANN ARBOR           3   Grandma Kelly's Homestead     Regina Murphy
#
#            ContactTitle         Address         City Region PostalCode  \
# 0    Purchasing Manager  49 Gilbert St.       London   None    EC1 4SD
# 1   Order Administrator  P.O. Box 78934  New Orleans     LA      70117
# 2  Sales Representative  707 Oxford Rd.    Ann Arbor     MI      48104
#
#   Country           Phone             Fax     HomePage
# 0      UK  (171) 555-2222            None         None
# 1     USA  (100) 555-4822            None  #CAJUN.HTM#
# 2     USA  (313) 555-5735  (313) 555-3349         None

# %% [markdown]
# ### `GROUP BY`
#
# The `GROUP BY` keyword groups rows before they are aggregated. `GROUP BY` is the SQL equivalent of Pandas' `.groupby()` method.

# %%
pd.read_sql("SELECT AVG(freight) FROM Orders;", db)
# Out:
#    AVG(freight)
# 0     80.627205

# %%
pd.read_sql("SELECT AVG(freight), ShipCountry FROM Orders GROUP BY 2;", db)
# Out:
#     AVG(freight)  ShipCountry
# 0      37.411250    Argentina
# 1     184.787500      Austria
# 2      67.375789      Belgium
# 3      58.797470       Brazil
# 4      73.269667       Canada
# 5      77.566111      Denmark
# 6      41.404091      Finland
# 7      80.723766       France
# 8      92.485902      Germany
# 9     145.012632      Ireland
# 10     30.872857        Italy
# 11     40.099286       Mexico
# 12     45.916667       Norway
# 13     25.105714       Poland
# 14     49.502308     Portugal
# 15     37.473478        Spain
# 16     87.502703       Sweden
# 17     76.029444  Switzerland
# 18     52.754821           UK
# 19    112.879426          USA
# 20     59.460435    Venezuela

# %%
pd.read_sql("SELECT AVG(freight), ShipCountry, ShipName FROM Orders GROUP BY 2, 3;", db)
# Out:
#     AVG(freight) ShipCountry                    ShipName
# 0      12.126667   Argentina  Cactus Comidas para llevar
# 1      61.328000   Argentina      Océano Atlántico Ltda.
# 2      43.836000   Argentina               Rancho grande
# 3     206.846333     Austria                Ernst Handel
# 4     118.611000     Austria            Piccolo und mehr
# ..           ...         ...                         ...
# 85     96.647143         USA        White Clover Markets
# 86     33.900000   Venezuela        GROSELLA-Restaurante
# 87     69.953333   Venezuela            HILARION-Abastos
# 88     52.457857   Venezuela           LILA-Supermercado
# 89     56.150833   Venezuela            LINO-Delicateses
#
# [90 rows x 3 columns]

# %%
pd.read_sql("SELECT AVG(freight), ShipCountry, COUNT(DISTINCT ShipName) FROM Orders GROUP BY 2;", db)
# Out:
#     AVG(freight)  ShipCountry  COUNT(DISTINCT ShipName)
# 0      37.411250    Argentina                         3
# 1     184.787500      Austria                         2
# 2      67.375789      Belgium                         2
# 3      58.797470       Brazil                         9
# 4      73.269667       Canada                         3
# 5      77.566111      Denmark                         2
# 6      41.404091      Finland                         2
# 7      80.723766       France                        10
# 8      92.485902      Germany                        12
# 9     145.012632      Ireland                         1
# 10     30.872857        Italy                         3
# 11     40.099286       Mexico                         5
# 12     45.916667       Norway                         1
# 13     25.105714       Poland                         1
# 14     49.502308     Portugal                         2
# 15     37.473478        Spain                         4
# 16     87.502703       Sweden                         2
# 17     76.029444  Switzerland                         2
# 18     52.754821           UK                         7
# 19    112.879426          USA                        13
# 20     59.460435    Venezuela                         4

# %%
query_1 = """
SELECT AVG(freight)
      , MAX(freight)
      , MIN(freight)
      , ShipCountry
      , COUNT(DISTINCT ShipName)
      FROM Orders GROUP BY 4
"""
pd.read_sql_query(query_1, db)
# Out:
#     AVG(freight)  MAX(freight)  MIN(freight)  ShipCountry  \
# 0      37.411250        217.86          0.33    Argentina
# 1     184.787500        789.95          5.29      Austria
# 2      67.375789        424.30          0.17      Belgium
# 3      58.797470        890.78          0.14       Brazil
# 4      73.269667        379.13          0.94       Canada
# 5      77.566111        299.09          2.92      Denmark
# 6      41.404091        180.45          0.59      Finland
# 7      80.723766       2000.00          0.02       France
# 8      92.485902       1007.64          0.15      Germany
# 9     145.012632        603.54         16.74      Ireland
# 10     30.872857        155.97          0.48        Italy
# 11     40.099286        218.15          0.40       Mexico
# 12     45.916667         93.63          4.62       Norway
# 13     25.105714         80.65          3.94       Poland
# 14     49.502308        202.24          1.27     Portugal
# 15     37.473478        175.32          1.25        Spain
# 16     87.502703        328.74          1.23       Sweden
# 17     76.029444        232.42          1.17  Switzerland
# 18     52.754821        288.43          0.90           UK
# 19    112.879426        830.75          0.20          USA
# 20     59.460435        210.19          0.12    Venezuela
#
#     COUNT(DISTINCT ShipName)
# 0                          3
# 1                          2
# 2                          2
# 3                          9
# 4                          3
# 5                          2
# 6                          2
# 7                         10
# 8                         12
# 9                          1
# 10                         3
# 11                         5
# 12                         1
# 13                         1
# 14                         2
# 15                         4
# 16                         2
# 17                         2
# 18                         7
# 19                        13
# 20                         4

# %% [markdown]
# ### `HAVING`
#
# The `WHERE` keyword puts conditions on the rows returned _before computing any aggregate functions._ So use `WHERE` to remove rows before aggregation.
#
# The `HAVING` keyword puts conditions on the rows returned _after computing any aggregate functions._ So use `HAVING` to remove rows after aggregation. `HAVING` is most useful for conditions on the result of an aggregate.

# %%
# It's an error to use WHERE to put a condition on an aggregated column.
pd.read_sql("SELECT AVG(freight) AS AVG_freight, ShipCountry FROM Orders GROUP BY 2 WHERE AVG_freight > 70;", db)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: near "WHERE": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-13-f80dce4ab02b> in <cell line: 2>()
#       1 # It's an error to use WHERE to put a condition on an aggregated column.
# ----> 2 pd.read_sql("SELECT AVG(freight) AS AVG_freight, ShipCountry FROM Orders GROUP BY 2 WHERE AVG_freight > 70;", db)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704     with pandasSQL_builder(con) as pandas_sql:
#     705         if isinstance(pandas_sql, SQLiteDatabase):
# --> 706             return pandas_sql.read_query(
#     707                 sql,
#     708                 index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT AVG(freight) AS AVG_freight, ShipCountry FROM Orders GROUP BY 2 WHERE AVG_freight > 70;': near "WHERE": syntax error

# %%
pd.read_sql("SELECT AVG(freight) AS AVG_freight, ShipCountry FROM Orders GROUP BY 2 HAVING AVG_freight > 70;", db)
# Out:
#    AVG_freight  ShipCountry
# 0   184.787500      Austria
# 1    73.269667       Canada
# 2    77.566111      Denmark
# 3    80.723766       France
# 4    92.485902      Germany
# 5   145.012632      Ireland
# 6    87.502703       Sweden
# 7    76.029444  Switzerland
# 8   112.879426          USA

# %%
query_1 = """
SELECT AVG(freight) as AVG_freight
      , MAX(freight) as MAX_freight
      , MIN(freight) as MIN_freight
      , ShipCountry
      , COUNT(DISTINCT ShipName) as COUNT_shipname
      FROM Orders
      GROUP BY 4
      HAVING AVG_freight > 50
      AND COUNT_shipname > 2
"""
pd.read_sql_query(query_1, db)
# Out:
#    AVG_freight  MAX_freight  MIN_freight ShipCountry  COUNT_shipname
# 0    58.797470       890.78         0.14      Brazil               9
# 1    73.269667       379.13         0.94      Canada               3
# 2    80.723766      2000.00         0.02      France              10
# 3    92.485902      1007.64         0.15     Germany              12
# 4    52.754821       288.43         0.90          UK               7
# 5   112.879426       830.75         0.20         USA              13
# 6    59.460435       210.19         0.12   Venezuela               4

# %% [markdown]
# # Mini Case

# %% [markdown]
# Selamat ! Kamu baru saja diterima bekerja sebagai seorang Jr. Data Analyst di perusahaan Nortwind Traders!. Hari ini adalah hari pertama kamu bekerja, dan manager kamu ingin kamu secara perlahan mengetahui seluk beluk dari perusahaan tempat kamu bekerja. Kamu diminta untuk mengerjakan beberapa tugas berikut menggunakan bantuan SQL yang sudah kamu pelajari sebelumnya.
# Tugas kamu adalah membuat query untuk menjawab beberapa tugas yang akan diberikan di bawah ini, kemudian kamu dapat memberikan komentar sesuai dengan hasil query kamu.
# Selamat bekerja!!

# %% [markdown]
# ### 6.1. Menganalisa aktivitas pemesanan

# %%
# tampilkan data pemesanan pada customer id VINET dengan tujuan negara France, dan memiliki nilai maksimal Freight lebih dari 10

# %%
import pandas as pd

df = pd.read_sql_query("SELECT * FROM Orders WHERE CustomerID = 'VINET' AND ShipCountry = 'France' AND Freight > 10;", db)

print(df)
# Out:
#    OrderID CustomerID  EmployeeID                OrderDate  \
# 0    10248      VINET           5  2014-07-04 08:00:00.000
# 1    10739      VINET           3  2015-11-12 10:00:00.000
#
#               RequiredDate              ShippedDate  ShipVia  Freight  \
# 0  2014-08-01 00:00:00.000  2014-07-16 00:00:00.000        3    32.38
# 1  2015-12-10 00:00:00.000  2015-11-17 00:00:00.000        3    11.08
#
#                     ShipName         ShipAddress ShipCity ShipRegion  \
# 0  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims       None
# 1  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims       None
#
#   ShipPostalCode ShipCountry
# 0          51100      France
# 1          51100      France

# %%
# tampilkan data pemesanan dengan pengecualian --> ship region tidak boleh bernilai NONE
# dan diurutkan dari nilai freight tertinggi dengan rentang nilai rata-rata freight antara 30 sampai 35

# %%
pd.read_sql("SELECT * FROM Orders WHERE ShipRegion IS NOT NULL AND Freight BETWEEN 30 AND 35 ORDER BY Freight DESC;", db)
# Out:
#     OrderID CustomerID  EmployeeID                OrderDate  \
# 0     10357      LILAS           1  2014-11-19 08:00:00.000
# 1     10405      LINOD           1  2015-01-06 01:00:00.000
# 2     10989      QUEDE           2  2016-03-31 00:00:00.000
# 3     10383      AROUT           8  2014-12-16 22:00:00.000
# 4     10567      HUNGO           1  2015-06-12 19:00:00.000
# 5     11016      AROUT           9  2016-04-10 03:00:00.000
# 6     10685      GOURL           4  2015-09-29 00:00:00.000
# 7     10936      GREAL           3  2016-03-09 00:00:00.000
# 8     10913      QUEEN           4  2016-02-26 07:00:00.000
# 9     10975      BOTTM           1  2016-03-25 21:00:00.000
# 10    10811      LINOD           8  2016-01-02 20:00:00.000
# 11    10385      SPLIR           1  2014-12-17 19:00:00.000
# 12    10486      HILAA           1  2015-03-26 17:00:00.000
# 13    10394      HUNGC           1  2014-12-25 12:00:00.000
# 14    10863      HILAA           4  2016-02-02 00:00:00.000
# 15    11064      SAVEA           1  2016-05-01 01:00:00.000
#
#                RequiredDate              ShippedDate  ShipVia  Freight  \
# 0   2014-12-17 00:00:00.000  2014-12-02 00:00:00.000        3    34.88
# 1   2015-02-03 00:00:00.000  2015-01-22 00:00:00.000        1    34.82
# 2   2016-04-28 00:00:00.000  2016-04-02 00:00:00.000        1    34.76
# 3   2015-01-13 00:00:00.000  2014-12-18 00:00:00.000        3    34.24
# 4   2015-07-10 00:00:00.000  2015-06-17 00:00:00.000        1    33.97
# 5   2016-05-08 00:00:00.000  2016-04-13 00:00:00.000        2    33.80
# 6   2015-10-13 00:00:00.000  2015-10-03 00:00:00.000        2    33.75
# 7   2016-04-06 00:00:00.000  2016-03-18 00:00:00.000        2    33.68
# 8   2016-03-26 00:00:00.000  2016-03-04 00:00:00.000        1    33.05
# 9   2016-04-22 00:00:00.000  2016-03-27 00:00:00.000        3    32.27
# 10  2016-01-30 00:00:00.000  2016-01-08 00:00:00.000        1    31.22
# 11  2015-01-14 00:00:00.000  2014-12-23 00:00:00.000        2    30.96
# 12  2015-04-23 00:00:00.000  2015-04-02 00:00:00.000        2    30.53
# 13  2015-01-22 00:00:00.000  2015-01-03 00:00:00.000        3    30.34
# 14  2016-03-02 00:00:00.000  2016-02-17 00:00:00.000        2    30.26
# 15  2016-05-29 00:00:00.000  2016-05-04 00:00:00.000        1    30.09
#
#                         ShipName  \
# 0              LILA-Supermercado
# 1               LINO-Delicateses
# 2                    Que Delícia
# 3                Around the Horn
# 4   Hungry Owl All-Night Grocers
# 5                Around the Horn
# 6            Gourmet Lanchonetes
# 7        Great Lakes Food Market
# 8                  Queen Cozinha
# 9          Bottom-Dollar Markets
# 10              LINO-Delicateses
# 11         Split Rail Beer & Ale
# 12              HILARION-Abastos
# 13    Hungry Coyote Import Store
# 14              HILARION-Abastos
# 15            Save-a-lot Markets
#
#                                        ShipAddress         ShipCity  \
# 0   Carrera 52 con Ave. Bolívar #65-98 Llano Largo     Barquisimeto
# 1                          Ave. 5 de Mayo Porlamar  I. de Margarita
# 2                          Rua da Panificadora, 12   Rio de Janeiro
# 3                    Brook Farm Stratford St. Mary       Colchester
# 4                                 8 Johnstown Road             Cork
# 5                    Brook Farm Stratford St. Mary       Colchester
# 6                                  Av. Brasil, 442         Campinas
# 7                                 2732 Baker Blvd.           Eugene
# 8                        Alameda dos Canàrios, 891        Sao Paulo
# 9                               23 Tsawassen Blvd.        Tsawassen
# 10                         Ave. 5 de Mayo Porlamar  I. de Margarita
# 11                                    P.O. Box 555           Lander
# 12      Carrera 22 con Ave. Carlos Soublette #8-35    San Cristóbal
# 13                  City Center Plaza 516 Main St.            Elgin
# 14      Carrera 22 con Ave. Carlos Soublette #8-35    San Cristóbal
# 15                                 187 Suffolk Ln.            Boise
#
#        ShipRegion ShipPostalCode ShipCountry
# 0            Lara           3508   Venezuela
# 1   Nueva Esparta           4980   Venezuela
# 2              RJ      02389-673      Brazil
# 3           Essex        CO7 6JX          UK
# 4        Co. Cork           None     Ireland
# 5           Essex        CO7 6JX          UK
# 6              SP      04876-786      Brazil
# 7              OR          97403         USA
# 8              SP      05487-020      Brazil
# 9              BC        T2F 8M4      Canada
# 10  Nueva Esparta           4980   Venezuela
# 11             WY          82520         USA
# 12        Táchira           5022   Venezuela
# 13             OR          97827         USA
# 14        Táchira           5022   Venezuela
# 15             ID          83720         USA

# %% [markdown]
# ### 6.2 Mengidentifikasi Customer

# %%
# tampilkan data jumlah customer di masing-masing country yang tinggal di Perancis dan USA

# %%
pd.read_sql("SELECT Country, COUNT(CustomerID) AS CustomerCount FROM Customers WHERE Country IN ('France', 'USA') GROUP BY Country;", db)
# Out:
#   Country  CustomerCount
# 0  France             11
# 1     USA             13

# %% [markdown]
# ### 6.3 Info Product dan category

# %%
# tampilkan info product berupa category id, harga termahal, harga termurah, dan diurutkan berdasarkan rata-rata stock dari terbesar ke terkecil
# kategori yang ditampilkan memiliki rata-rata stock lebih dari 40

# %%
pd.read_sql("SELECT CategoryID, MAX(UnitPrice) AS MaxPrice, MIN(UnitPrice) AS MinPrice, AVG(UnitsInStock) AS AvgStock FROM Products GROUP BY CategoryID HAVING AVG(UnitsInStock) > 40 ORDER BY AvgStock DESC;", db)
# Out:
#    CategoryID  MaxPrice  MinPrice   AvgStock
# 0           8      62.5       6.0  58.416667
# 1           1     263.5       4.5  46.583333
# 2           5      38.0       7.0  44.000000
# 3           2      43.9      10.0  42.250000
